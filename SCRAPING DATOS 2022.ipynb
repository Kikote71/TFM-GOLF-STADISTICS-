# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\NAME AVG ROUNDS YEAR.csv'

# Cargar el archivo CSV en un DataFrame
data_frame = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frame.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER     AVG  TOTAL STROKES  \
# 0     1         0      46046  Scottie Scheffler  68.598           5463
# 1     2         1      28237       Rory McIlroy  68.808           3870
# 2     3        -1      46970           Jon Rahm  68.811           4327
# 3     4         3      35450    Patrick Cantlay  69.206           4411
# 4     5         0      30911    Tommy Fleetwood  69.210           4583
#
#    TOTAL ADJUSTMENT  TOTAL ROUNDS
# 0            24.812            80
# 1           -16.761            56
# 2             8.098            63
# 3            18.179            64
# 4           -15.166            66

# %%
# Agregar la columna "YEAR" con el valor "2021"
data_frame['YEAR'] = 2022

# %%
# Seleccionar solo las columnas que deseas mantener
columns_to_keep = ['PLAYER_ID', 'PLAYER', 'AVG', 'TOTAL ROUNDS', 'YEAR']
data_frame = data_frame.loc[:, columns_to_keep]

# %%
data_frame.head()
# Out:
#    PLAYER_ID             PLAYER     AVG  TOTAL ROUNDS  YEAR
# 0      46046  Scottie Scheffler  68.598            80  2022
# 1      28237       Rory McIlroy  68.808            56  2022
# 2      46970           Jon Rahm  68.811            63  2022
# 3      35450    Patrick Cantlay  69.206            64  2022
# 4      30911    Tommy Fleetwood  69.210            66  2022

# %%
# Ahora vamos ir cargando diferentes DF y vamos a ir ensamblando por año las estafisticas que necesitamos

# Primero voy a ir poniendo nombres a las columnas para que no haya confusiones

data_frame.rename(columns={'AVG': 'AVG_TOTAL_FOR_ROUND'}, inplace=True)
data_frame.rename(columns={'PLAYER': 'PLAYER_NAME'}, inplace=True)
data_frame.rename(columns={'TOTAL ROUNDS': 'TOTAL_ROUNDS'}, inplace=True)

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022

# %%
# VAMOS A INCORPORAR LA ESTADISTICA AVG DRIVER DISTANCE

# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\DRIVING DISTANCE AVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameDD = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameDD.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID            PLAYER    AVG  TOTAL DISTANCE  \
# 0     1         0      28237      Rory McIlroy  325.8           33883
# 1     2         0      51491  Brandon Matthews  321.2           35330
# 2     3         0      57366     Cameron Young  317.1           44388
# 3     4         0      52372     Cameron Champ  316.1           35398
# 4     5         0      33948     Byeong Hun An  316.0           61295
#
#    TOTAL DRIVES
# 0           104
# 1           110
# 2           140
# 3           112
# 4           194

# %%
data_frameDD = data_frameDD[['PLAYER_ID', 'AVG']]

# %%
data_frameDD.rename(columns={'AVG': 'AVG_DRIVER_DISTANCE'}, inplace=True)

# %%
data_frameDD.head()
# Out:
#    PLAYER_ID  AVG_DRIVER_DISTANCE
# 0      28237                325.8
# 1      51491                321.2
# 2      57366                317.1
# 3      52372                316.1
# 4      33948                316.0

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameDD, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE
# 0                310.1
# 1                325.8
# 2                313.3
# 3                307.7
# 4                302.2

# %%
# VAMOS A INCORPORAR LA ESTADISTICA AVG FAIRWAY PERCENTAJE

# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\FAIRWAY PERCENTAJE.csv'

# Cargar el archivo CSV en un DataFrame
data_frameFP = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameFP.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID          PLAYER       %  FAIRWAYS HIT  \
# 0     1         1      34098  Russell Henley  71.02%           615
# 1     2         1      19803     Ryan Armour  69.93%           579
# 2     3         1      26596      Ryan Moore  68.82%           490
# 3     4         1      46414       Aaron Rai  68.37%           789
# 4     5         2      37455      Si Woo Kim  68.15%           691
#
#    POSSIBLE FAIRWAYS  RELATIVE TO PAR
# 0                866            -0.22
# 1                828            -0.15
# 2                712            -0.18
# 3               1154            -0.21
# 4               1014            -0.20

# %%
data_frameFP.rename(columns={'%': 'AVG_FAIRWAY'}, inplace=True)

# %%
data_frameFP = data_frameFP[['PLAYER_ID', 'AVG_FAIRWAY']]

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameFP, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY
# 0                310.1      62.28%
# 1                325.8      54.65%
# 2                313.3      55.89%
# 3                307.7      65.87%
# 4                302.2      60.97%

# %%
# VAMOS A INCORPORAR LA ESTADISTICA PEDEX POINTS

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\FEDEX 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameFPOINTS = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameFPOINTS.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER  POINTS  # OF WINS  \
# 0     1         0      46970           Jon Rahm    3320          4
# 1     2         0      46046  Scottie Scheffler    3146          2
# 2     3         0      28237       Rory McIlroy    2304          2
# 3     4         0      39977           Max Homa    2128          2
# 4     5         0      51766      Wyndham Clark    1944          2
#
#    # OF TOP 10'S  POINTS BEHIND LEAD
# 0             10                   0
# 1             15                 174
# 2             10                1016
# 3              9                1192
# 4              7                1376

# %%
data_frameFPOINTS.rename(columns={'POINTS': 'FEDEX_POINTS'}, inplace=True)

# %%
data_frameFPOINTS = data_frameFPOINTS[['PLAYER_ID', 'FEDEX_POINTS']]

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameFPOINTS, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS
# 0                310.1      62.28%        3146.0
# 1                325.8      54.65%        2304.0
# 2                313.3      55.89%        3320.0
# 3                307.7      65.87%        1443.0
# 4                302.2      60.97%        1184.0

# %%
# VAMOS A INCORPORAR LA ESTADISTICA GREEN IN REGULATIONS

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\GIR 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameGIR = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameGIR.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER       %  GREENS HIT  # HOLES  \
# 0     1         0      46046  Scottie Scheffler  74.03%        1066     1440
# 1     2         0      45242           Kevin Yu  72.96%         696      954
# 2     3         0      46970           Jon Rahm  70.99%         805     1134
# 3     4         0      52375          Doug Ghim  70.56%         978     1386
# 4     5         0      50525    Collin Morikawa  70.53%         876     1242
#
#    RELATIVE/PAR
# 0         -0.33
# 1         -0.30
# 2         -0.36
# 3         -0.26
# 4         -0.30

# %%
data_frameGIR.rename(columns={'%': 'AVG_GIR'}, inplace=True)

# %%
data_frameGIR = data_frameGIR[['PLAYER_ID', 'AVG_GIR']]

# %%
# ENSAMBLAMOS EL GIR DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameGIR, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR
# 0                310.1      62.28%        3146.0  74.03%
# 1                325.8      54.65%        2304.0  67.46%
# 2                313.3      55.89%        3320.0  70.99%
# 3                307.7      65.87%        1443.0  69.53%
# 4                302.2      60.97%        1184.0  63.72%

# %%
# VAMOS A INCORPORAR LA ESTADISTICA MONEY

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\MONEY 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameMO = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameMO.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER      MONEY  YTD VICTORIES
# 0     1         0      46046  Scottie Scheffler  $19254342            2.0
# 1     2         0      46970           Jon Rahm  $16383608            4.0
# 2     3         0      28237       Rory McIlroy  $12931008            2.0
# 3     4         1      46717     Viktor Hovland  $10512235            1.0
# 4     5        -1      51766      Wyndham Clark  $10425490            2.0

# %%
data_frameMO = data_frameMO[['PLAYER_ID', 'MONEY']]

# %%
# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameMO, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 3

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\P3 AVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP3 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP3.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER STATUS  PAR 3 AVG  TOTAL PAR
# 0     1         0      39977           Max Homa    -20       2.93        894
# 1     2         0      46970           Jon Rahm    -18       2.93        768
# 2     3         1      47591          Eric Cole    -14       2.97       1269
# 3     4        -1      32102      Rickie Fowler     -9       2.97       1044
# 4     5         0      46046  Scottie Scheffler     -7       2.98        984

# %%
data_frameP3.rename(columns={'PAR 3 AVG': 'PAR_3_AVG'}, inplace=True)
data_frameP3 = data_frameP3[['PLAYER_ID', 'PAR_3_AVG']]

# %%
# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP3, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  PAR_3_AVG
# 0                310.1      62.28%        3146.0  74.03%  $19254342       2.98
# 1                325.8      54.65%        2304.0  67.46%  $12931008       2.98
# 2                313.3      55.89%        3320.0  70.99%  $16383608       2.93
# 3                307.7      65.87%        1443.0  69.53%  $10040998       3.08
# 4                302.2      60.97%        1184.0  63.72%   $6330891       3.01

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 4

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\P4 AVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP4 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP4.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER STATUS  PAR 4 AVG  TOTAL PAR
# 0     1         0      46046  Scottie Scheffler    -73       3.92       3456
# 1     2         1      35450    Patrick Cantlay    -50       3.93       2760
# 2     3        -1      47993     Denny McCarthy    -44       3.96       3980
# 3     4         0      28089          Jason Day    -36       3.95       3088
# 4     5         2      46717     Viktor Hovland    -30       3.97       3452

# %%
data_frameP4.rename(columns={'PAR 4 AVG': 'PAR_4_AVG'}, inplace=True)
data_frameP4 = data_frameP4[['PLAYER_ID', 'PAR_4_AVG']]

# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP4, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG
# 0       2.98       3.92
# 1       2.98       3.96
# 2       2.93       3.96
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 5

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\P5 AVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP5 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP5.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID          PLAYER  STATUS  PAR 5 AVG  TOTAL PAR
# 0     1         0      39971      Sungjae Im    -152       4.47       1430
# 1     2         0      51766   Wyndham Clark    -147       4.52       1540
# 2     3         0      47591       Eric Cole    -140       4.55       1560
# 3     3         2      36799  Stephan Jaeger    -140       4.57       1620
# 4     5        -2      54421   Garrick Higgo    -139       4.55       1540

# %%
data_frameP5.rename(columns={'PAR 5 AVG': 'PAR_5_AVG'}, inplace=True)
data_frameP5 = data_frameP5[['PLAYER_ID', 'PAR_5_AVG']]

# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP5, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG
# 0       2.98       3.92       4.45
# 1       2.98       3.96       4.55
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PUTT AVERAGE

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\PUTT AVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_framePAVG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_framePAVG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  GIR PUTTS  GREENS HIT  \
# 0     1         0      55789  Taylor Montgomery  1.659       1516         914
# 1     2         0      46970           Jon Rahm  1.699       1368         805
# 2     3         1      37275          Sam Ryder  1.700       1710        1006
# 3     4        -1      39977           Max Homa  1.703       1495         878
# 4     5         8      30911    Tommy Fleetwood  1.704       1290         757
#
#   BIRDIE CONVERSION
# 0            38.93%
# 1            36.75%
# 2            34.13%
# 3            35.43%
# 4            34.79%

# %%
data_framePAVG.rename(columns={'AVG': 'AVG_PUTT'}, inplace=True)

# %%
data_framePAVG = data_framePAVG[['PLAYER_ID', 'AVG_PUTT']]

# %%
# ENSAMBLAMOS EL AVG_PUTT DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_framePAVG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT
# 0       2.98       3.92       4.45     1.730
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA SCRAMBLING PROMEDIO

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\SCAVG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSCAVG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSCAVG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID         PLAYER       %  PAR OR BETTER  MISSED GIR
# 0     1         0      27644   Brian Harman  67.44%            321         476
# 1     2         0      28089      Jason Day  66.82%            286         428
# 2     3         0      24925  Jonathan Byrd  66.35%            207         312
# 3     4         0      23108    Matt Kuchar  65.76%            315         479
# 4     5         3      39324     J.J. Spaun  65.74%            309         470

# %%
data_frameSCAVG.rename(columns={'%': 'AVG_SCRAMBLING'}, inplace=True)
data_frameSCAVG = data_frameSCAVG[['PLAYER_ID', 'AVG_SCRAMBLING']]

# %%
# ENSAMBLAMOS EL AVG_PUTT DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSCAVG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED APPROACH THE GREEN 

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\SG APP 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGAPP = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGAPP.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL SG:APP  \
# 0     1         0      46046  Scottie Scheffler  1.258        83.003
# 1     2         0      50525    Collin Morikawa  1.025        55.358
# 2     3         0      46970           Jon Rahm  0.901        46.828
# 3     4         0      28237       Rory McIlroy  0.854        42.718
# 4     5         0      48081  Xander Schauffele  0.842        45.469
#
#    MEASURED ROUNDS
# 0               66
# 1               54
# 2               52
# 3               50
# 4               54

# %%
data_frameSGAPP.rename(columns={'AVG': 'AVG_SG_APPROACH'}, inplace=True)
data_frameSGAPP = data_frameSGAPP[['PLAYER_ID', 'AVG_SG_APPROACH']]

# %%
# ENSAMBLAMOS EL AVG_SG_APPROACH DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGAPP, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING  AVG_SG_APPROACH
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED ARROUND THE GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\SG ATG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGATG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGATG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL SG:ARG  \
# 0     1         0      24925      Jonathan Byrd  0.525        16.805
# 1     2         0      22371     Aaron Baddeley  0.475        25.673
# 2     3         0      30927       Brendon Todd  0.441        33.070
# 3     4         0      33948      Byeong Hun An  0.438        37.244
# 4     5         0      46046  Scottie Scheffler  0.412        27.187
#
#    MEASURED ROUNDS
# 0               32
# 1               54
# 2               75
# 3               85
# 4               66

# %%
data_frameSGATG.rename(columns={'AVG': 'AVG_SG_ATG'}, inplace=True)
data_frameSGATG = data_frameSGATG[['PLAYER_ID', 'AVG_SG_ATG']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGATG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING  AVG_SG_APPROACH  \
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED ARROUND THE GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\SG PUTT 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSPUTT = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSPUTT.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL SG:PUTTING  \
# 0     1         0      46442   Maverick McNealy  1.058            48.662
# 1     2         0      55789  Taylor Montgomery  0.884            67.220
# 2     3         0      47993     Denny McCarthy  0.751            60.852
# 3     4         1      48081  Xander Schauffele  0.651            35.136
# 4     5         5      34256      Andrew Putnam  0.645            52.886
#
#    MEASURED ROUNDS
# 0               46
# 1               76
# 2               81
# 3               54
# 4               82

# %%
data_frameSPUTT.rename(columns={'AVG': 'AVG_SG_PUTTING'}, inplace=True)
data_frameSPUTT = data_frameSPUTT[['PLAYER_ID', 'AVG_SG_PUTTING']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSPUTT, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING  AVG_SG_APPROACH  \
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED TOTAL

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2021\SG TOTAL 2021.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGTOT = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGTOT.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL SG:T  \
# 0     1         0      28237       Rory McIlroy  2.115     109.968
# 1     2         0      40098   Matt Fitzpatrick  1.792      86.035
# 2     3         0      47483     Will Zalatoris  1.767     100.723
# 3     4         0      33448      Justin Thomas  1.680     102.492
# 4     5         0      46046  Scottie Scheffler  1.677     110.666
#
#    TOTAL SG:T2G  TOTAL SG:P  MEASURED ROUNDS
# 0        84.208      25.762               52
# 1        65.650      20.385               48
# 2       100.913      -0.188               57
# 3        96.939       5.553               61
# 4        97.362      13.304               66

# %%
data_frameSGTOT.rename(columns={'AVG': 'AVG_SG_TOTAL'}, inplace=True)
data_frameSGTOT = data_frameSGTOT[['PLAYER_ID', 'AVG_SG_TOTAL']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGTOT, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING  AVG_SG_APPROACH  \
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED TEE TO GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\SG TTG 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGTTG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGTTG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  SG:OTT  SG:APR  \
# 0     1         0      46046  Scottie Scheffler  2.690   1.034   1.258
# 1     2         0      28237       Rory McIlroy  2.110   1.075   0.854
# 2     3         0      46970           Jon Rahm  1.612   0.500   0.901
# 3     4         0      50525    Collin Morikawa  1.605   0.459   1.025
# 4     5         0      35450    Patrick Cantlay  1.585   0.848   0.488
#
#    SG:ARG  MEASURED ROUNDS
# 0   0.412               66
# 1   0.315               50
# 2   0.153               52
# 3   0.058               54
# 4   0.157               54

# %%
data_frameSGTTG

data_frameSGTTG.rename(columns={'AVG': 'AVG_SG_TTG'}, inplace=True)
data_frameSGTTG = data_frameSGTTG[['PLAYER_ID', 'AVG_SG_TTG']]

# %%
# ENSAMBLAMOS EL AVG_SG_TTG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGTTG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342
# 1                325.8      54.65%        2304.0  67.46%  $12931008
# 2                313.3      55.89%        3320.0  70.99%  $16383608
# 3                307.7      65.87%        1443.0  69.53%  $10040998
# 4                302.2      60.97%        1184.0  63.72%   $6330891
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT AVG_SCRAMBLING  AVG_SG_APPROACH  \
# ...

# %%
# VAMOS A INCORPORAR LA ESTADISTICA TOP 10 Y WININGS
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2022\WINNERS 2022.csv'

# Cargar el archivo CSV en un DataFrame
data_frameTOP10 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameTOP10.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER  TOP 10  1ST  2ND  3RD
# 0     1         0      46046  Scottie Scheffler      15    2    1    5
# 1     2         0      28237       Rory McIlroy      11    2    2    2
# 2     3         1      39977           Max Homa      10    2    1    1
# 3     3        -1      46970           Jon Rahm      10    4    2    1
# 4     5         1      35450    Patrick Cantlay       9    0    2    2

# %%
data_frameTOP10.rename(columns={'1ST': 'WINS'}, inplace=True)
data_frameTOP10.rename(columns={'TOP 10': 'TOP10'}, inplace=True)
data_frameTOP10 = data_frameTOP10[['PLAYER_ID', 'WINS', 'TOP10']]

# %%
# ENSAMBLAMOS EL AVG_SG_TTG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameTOP10, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46046  Scottie Scheffler               68.598            80  2022
# 1      28237       Rory McIlroy               68.808            56  2022
# 2      46970           Jon Rahm               68.811            63  2022
# 3      35450    Patrick Cantlay               69.206            64  2022
# 4      30911    Tommy Fleetwood               69.210            66  2022
#
#    AVG_DRIVER_DISTANCE AVG_FAIRWAY  FEDEX_POINTS AVG_GIR      MONEY  ...  \
# 0                310.1      62.28%        3146.0  74.03%  $19254342  ...
# 1                325.8      54.65%        2304.0  67.46%  $12931008  ...
# 2                313.3      55.89%        3320.0  70.99%  $16383608  ...
# 3                307.7      65.87%        1443.0  69.53%  $10040998  ...
# 4                302.2      60.97%        1184.0  63.72%   $6330891  ...
#
#    PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH AVG_SG_ATG  \
# ...

# %%
# Define el orden deseado de las columnas
column_order = ['PLAYER_ID', 'PLAYER_NAME', 'TOTAL_ROUNDS', 'AVG_FAIRWAY', 'AVG_SCRAMBLING', 'AVG_TOTAL_FOR_ROUND', 'AVG_DRIVER_DISTANCE','AVG_SG_APPROACH', 'AVG_GIR', 'AVG_PUTT', 'AVG_SG_ATG', 'AVG_SG_PUTTING', 'AVG_SG_TOTAL', 'AVG_SG_TTG','PAR_5_AVG','PAR_4_AVG','PAR_3_AVG', 'WINS', 'TOP10', 'YEAR', 'FEDEX_POINTS', 'MONEY']

# Reordena las columnas en el DataFrame
data_frame = data_frame[column_order]

# Mostrar el DataFrame con las columnas ordenadas
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS AVG_FAIRWAY AVG_SCRAMBLING  \
# 0      46046  Scottie Scheffler            80      62.28%         63.90%
# 1      28237       Rory McIlroy            56      54.65%         60.37%
# 2      46970           Jon Rahm            63      55.89%         62.01%
# 3      35450    Patrick Cantlay            64      65.87%         63.53%
# 4      30911    Tommy Fleetwood            66      60.97%         65.20%
#
#    AVG_TOTAL_FOR_ROUND  AVG_DRIVER_DISTANCE  AVG_SG_APPROACH AVG_GIR  \
# 0               68.598                310.1            1.258  74.03%
# 1               68.808                325.8            0.854  67.46%
# 2               68.811                313.3            0.901  70.99%
# 3               69.206                307.7            0.488  69.53%
# 4               69.210                302.2            0.426  63.72%
#
#    AVG_PUTT  ...  AVG_SG_TOTAL  AVG_SG_TTG  PAR_5_AVG  PAR_4_AVG  PAR_3_AVG  \
# ...

# %%
num_rows, num_columns = data_frame.shape
print("Número de filas:", num_rows)
print("Número de columnas:", num_columns)
# Out:
# Número de filas: 188
# Número de columnas: 22

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID               0
# PLAYER_NAME             0
# TOTAL_ROUNDS            0
# AVG_FAIRWAY             0
# AVG_SCRAMBLING          0
# AVG_TOTAL_FOR_ROUND     0
# AVG_DRIVER_DISTANCE     0
# AVG_SG_APPROACH         0
# AVG_GIR                 0
# AVG_PUTT                0
# AVG_SG_ATG              0
# AVG_SG_PUTTING          0
# AVG_SG_TOTAL           50
# AVG_SG_TTG              0
# PAR_5_AVG               0
# PAR_4_AVG               0
# PAR_3_AVG               0
# WINS                   43
# TOP10                  43
# YEAR                    0
# FEDEX_POINTS            1
# MONEY                   1
# dtype: int64

# %%
# IMPORTANTE, COMO ESTA TEMPORADA AUN NO HA ACABADO, HAY 50 PLAYERS QUE NO TIENEN AVG_SG_TOTAL Y ES UNA ESTADISTICA RELEVANTE, POR ESO VAMOS A APLICAR A ESOS NAN EL VARLO MEDIO

# Calcular el valor medio de la columna AVG_SG_TOTAL sin incluir los NaN
avg_sg_total_mean = data_frame['AVG_SG_TOTAL'].mean(skipna=True)

# Reemplazar los NaN por el valor medio calculado
data_frame['AVG_SG_TOTAL'].fillna(avg_sg_total_mean, inplace=True)

# Reemplazamos el resto de nan por 0, por que son vairiables numericas

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID               0
# PLAYER_NAME             0
# TOTAL_ROUNDS            0
# AVG_FAIRWAY             0
# AVG_SCRAMBLING          0
# AVG_TOTAL_FOR_ROUND     0
# AVG_DRIVER_DISTANCE     0
# AVG_SG_APPROACH         0
# AVG_GIR                 0
# AVG_PUTT                0
# AVG_SG_ATG              0
# AVG_SG_PUTTING          0
# AVG_SG_TOTAL            0
# AVG_SG_TTG              0
# PAR_5_AVG               0
# PAR_4_AVG               0
# PAR_3_AVG               0
# WINS                   43
# TOP10                  43
# YEAR                    0
# FEDEX_POINTS            1
# MONEY                   1
# dtype: int64

# %%
# Reemplazar los valores NaN por 0 en todo el DataFrame
data_frame = data_frame.fillna(0)

# Mostrar el DataFrame con los valores NaN reemplazados por 0
print(data_frame)
# Out:
#      PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS AVG_FAIRWAY AVG_SCRAMBLING  \
# 0        46046  Scottie Scheffler            80      62.28%         63.90%
# 1        28237       Rory McIlroy            56      54.65%         60.37%
# 2        46970           Jon Rahm            63      55.89%         62.01%
# 3        35450    Patrick Cantlay            64      65.87%         63.53%
# 4        30911    Tommy Fleetwood            66      60.97%         65.20%
# ..         ...                ...           ...         ...            ...
# 183      33410      Andrew Landry            63      64.28%         59.86%
# 184      27095        Nick Watney            62      47.75%         53.72%
# 185      32662     Michael Gligic            59      51.11%         54.10%
# 186      28420         Ryan Brehm            74      47.41%         53.89%
# 187      51491   Brandon Matthews            55      51.39%         50.43%
#
# ...

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID              0
# PLAYER_NAME            0
# TOTAL_ROUNDS           0
# AVG_FAIRWAY            0
# AVG_SCRAMBLING         0
# AVG_TOTAL_FOR_ROUND    0
# AVG_DRIVER_DISTANCE    0
# AVG_SG_APPROACH        0
# AVG_GIR                0
# AVG_PUTT               0
# AVG_SG_ATG             0
# AVG_SG_PUTTING         0
# AVG_SG_TOTAL           0
# AVG_SG_TTG             0
# PAR_5_AVG              0
# PAR_4_AVG              0
# PAR_3_AVG              0
# WINS                   0
# TOP10                  0
# YEAR                   0
# FEDEX_POINTS           0
# MONEY                  0
# dtype: int64

# %%
data_frame2022 = data_frame

# %%
# Ruta para guardar el archivo CSV
ruta_guardado = r'C:\Users\kikot\Desktop\TFM GOLF\data_frame2022.csv'

# Exportar el DataFrame a un archivo CSV en la ruta especificada
data_frame2022.to_csv(ruta_guardado, index=False)

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID              0
# PLAYER_NAME            0
# TOTAL_ROUNDS           0
# AVG_FAIRWAY            0
# AVG_SCRAMBLING         0
# AVG_TOTAL_FOR_ROUND    0
# AVG_DRIVER_DISTANCE    0
# AVG_SG_APPROACH        0
# AVG_GIR                0
# AVG_PUTT               0
# AVG_SG_ATG             0
# AVG_SG_PUTTING         0
# AVG_SG_TOTAL           0
# AVG_SG_TTG             0
# PAR_5_AVG              0
# PAR_4_AVG              0
# PAR_3_AVG              0
# WINS                   0
# TOP10                  0
# YEAR                   0
# FEDEX_POINTS           0
# MONEY                  0
# dtype: int64

# %%
import pandas as pd

# Definir la ruta de los archivos CSV
ruta = 'C:/Users/kikot/Desktop/TFM GOLF/'

# Leer los archivos CSV y crear los DataFrames
data_frame2019 = pd.read_csv(ruta + 'data_frame2019.csv')
data_frame2020 = pd.read_csv(ruta + 'data_frame2020.csv')
data_frame2021 = pd.read_csv(ruta + 'data_frame2021.csv')
data_frame2022 = pd.read_csv(ruta + 'data_frame2022.csv')

# Concatenar los DataFrames en uno solo
DF_Definitivo = pd.concat([data_frame2019, data_frame2020, data_frame2021, data_frame2022], ignore_index=True)

# Mostrar el DataFrame resultante
print(DF_Definitivo)
# Out:
#      PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS AVG_FAIRWAY AVG_SCRAMBLING  \
# 0        29221       Webb Simpson            52       67.42          64.47
# 1        46970           Jon Rahm            58       63.16          64.52
# 2        33448      Justin Thomas            66       57.53          63.16
# 3        28237       Rory McIlroy            60       55.73          60.63
# 4        48081  Xander Schauffele            70        59.6          66.49
# ..         ...                ...           ...         ...            ...
# 763      33410      Andrew Landry            63      64.28%         59.86%
# 764      27095        Nick Watney            62      47.75%         53.72%
# 765      32662     Michael Gligic            59      51.11%         54.10%
# 766      28420         Ryan Brehm            74      47.41%         53.89%
# 767      51491   Brandon Matthews            55      51.39%         50.43%
#
# ...

# %%
# Ruta para guardar el archivo CSV
ruta_guardado = r'C:\Users\kikot\Desktop\TFM GOLF\DF_Definitivo.csv'

# Exportar el DataFrame a un archivo CSV en la ruta especificada
DF_Definitivo.to_csv(ruta_guardado, index=False)
