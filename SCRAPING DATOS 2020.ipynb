# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\NAME AVG ROUNDS YEAR.csv'

# Cargar el archivo CSV en un DataFrame
data_frame = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frame.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER     AVG  TOTAL STROKES  \
# 0     1         0      46970           Jon Rahm  69.300           5316
# 1     2         0      30925     Dustin Johnson  69.619           5011
# 2     3         0      26329   Louis Oosthuizen  69.714           5159
# 3     4         0      47959  Bryson DeChambeau  69.728           5566
# 4     5         0      35450    Patrick Cantlay  69.736           5413
#
#   TOTAL ADJUSTMENT  TOTAL ROUNDS
# 0           20.067            77
# 1            1.597            72
# 2           - .200            74
# 3           12.233            80
# 4           26.413            78

# %%
# Agregar la columna "YEAR" con el valor "2020"
data_frame['YEAR'] = 2020

# %%
# Seleccionar solo las columnas que deseas mantener
columns_to_keep = ['PLAYER_ID', 'PLAYER', 'AVG', 'TOTAL ROUNDS', 'YEAR']
data_frame = data_frame.loc[:, columns_to_keep]

# %%
data_frame.head()
# Out:
#    PLAYER_ID             PLAYER     AVG  TOTAL ROUNDS  YEAR
# 0      46970           Jon Rahm  69.300            77  2020
# 1      30925     Dustin Johnson  69.619            72  2020
# 2      26329   Louis Oosthuizen  69.714            74  2020
# 3      47959  Bryson DeChambeau  69.728            80  2020
# 4      35450    Patrick Cantlay  69.736            78  2020

# %%
# Ahora vamos ir cargando diferentes DF y vamos a ir ensamblando por año las estafisticas que necesitamos

# Primero voy a ir poniendo nombres a las columnas para que no haya confusiones

data_frame.rename(columns={'AVG': 'AVG_TOTAL_FOR_ROUND'}, inplace=True)
data_frame.rename(columns={'PLAYER': 'PLAYER_NAME'}, inplace=True)
data_frame.rename(columns={'TOTAL ROUNDS': 'TOTAL_ROUNDS'}, inplace=True)

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020

# %%
# VAMOS A INCORPORAR LA ESTADISTICA AVG DRIVER DISTANCE

# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\DRIVING DISTANCE AVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameDD = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameDD.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL DISTANCE  \
# 0     1         0      47959  Bryson DeChambeau  323.7           51790
# 1     2         0      28237       Rory McIlroy  319.3           47252
# 2     3         0      52372      Cameron Champ  317.1           47568
# 3     4         0      56278      Matthew Wolff  315.9           34748
# 4     5         0      56762        Will Gordon  315.0           55434
#
#    TOTAL DRIVES
# 0           160
# 1           148
# 2           150
# 3           110
# 4           176

# %%
data_frameDD = data_frameDD[['PLAYER_ID', 'AVG']]

# %%
data_frameDD.rename(columns={'AVG': 'AVG_DRIVER_DISTANCE'}, inplace=True)

# %%
data_frameDD.head()
# Out:
#    PLAYER_ID  AVG_DRIVER_DISTANCE
# 0      47959                323.7
# 1      28237                319.3
# 2      52372                317.1
# 3      56278                315.9
# 4      56762                315.0

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameDD, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE
# 0                309.0
# 1                312.9
# 2                297.8
# 3                323.7
# 4                302.8

# %%
# VAMOS A INCORPORAR LA ESTADISTICA AVG FAIRWAY PERCENTAJE

# %%
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\FAIRWAY PERCENTAJE.csv'

# Cargar el archivo CSV en un DataFrame
data_frameFP = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameFP.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID         PLAYER      %  FAIRWAYS HIT  \
# 0     1         0      30927   Brendon Todd  75.15           747
# 1     2         0      26476    Chez Reavie  74.50           739
# 2     3         0      31560   Brian Stuard  73.67           901
# 3     4         0      19803    Ryan Armour  73.39           684
# 4     5         0      45526  Abraham Ancer  71.04           802
#
#    POSSIBLE FAIRWAYS  RELATIVE TO PAR
# 0                994            -0.18
# 1                992            -0.16
# 2               1223            -0.15
# 3                932            -0.18
# 4               1129            -0.22

# %%
data_frameFP.rename(columns={'%': 'AVG_FAIRWAY'}, inplace=True)

# %%
data_frameFP = data_frameFP[['PLAYER_ID', 'AVG_FAIRWAY']]

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameFP, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY
# 0                309.0        62.53
# 1                312.9        57.03
# 2                297.8        62.40
# 3                323.7        54.78
# 4                302.8        60.21

# %%
# VAMOS A INCORPORAR LA ESTADISTICA PEDEX POINTS

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\FEDEX 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameFPOINTS = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameFPOINTS.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID           PLAYER  POINTS  # OF WINS  \
# 0     1         0      50525  Collin Morikawa    2171          2
# 1     2         0      34046    Jordan Spieth    2139          1
# 2     3         0      35450  Patrick Cantlay    2056          2
# 3     4         0      34099   Harris English    2039          2
# 4     5         0      46970         Jon Rahm    2003          1
#
#    # OF TOP 10'S  POINTS BEHIND LEAD
# 0              8                 0.0
# 1              9                32.0
# 2              5               115.0
# 3              8               132.0
# 4             12               168.0

# %%
data_frameFPOINTS.rename(columns={'POINTS': 'FEDEX_POINTS'}, inplace=True)

# %%
data_frameFPOINTS = data_frameFPOINTS[['PLAYER_ID', 'FEDEX_POINTS']]

# %%
# ENSAMBLAMOS EL DRIVER DISTANCE DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameFPOINTS, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS
# 0                309.0        62.53        2003.0
# 1                312.9        57.03        1510.0
# 2                297.8        62.40        1877.0
# 3                323.7        54.78        1910.0
# 4                302.8        60.21        2056.0

# %%
# VAMOS A INCORPORAR LA ESTADISTICA GREEN IN REGULATIONS

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\GIR 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameGIR = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameGIR.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER      %  GREENS HIT  # HOLES  \
# 0     1         0      22056      Cameron Percy  72.58        1006     1386
# 1     2         0      46970           Jon Rahm  71.93         997     1386
# 2     3         0      31646    Emiliano Grillo  71.47        1235     1728
# 3     4         0      36871    Matthew NeSmith  71.09        1126     1584
# 4     5         0      48045  Michael Gellerman  70.80         599      846
#
#    RELATIVE/PAR
# 0         -0.25
# 1         -0.34
# 2         -0.29
# 3         -0.25
# 4         -0.22

# %%
data_frameGIR.rename(columns={'%': 'AVG_GIR'}, inplace=True)

# %%
data_frameGIR = data_frameGIR[['PLAYER_ID', 'AVG_GIR']]

# %%
# ENSAMBLAMOS EL GIR DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameGIR, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR
# 0                309.0        62.53        2003.0    71.93
# 1                312.9        57.03        1510.0    66.67
# 2                297.8        62.40        1877.0    67.64
# 3                323.7        54.78        1910.0    67.15
# 4                302.8        60.21        2056.0    70.16

# %%
# VAMOS A INCORPORAR LA ESTADISTICA MONEY

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\MONEY 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameMO = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameMO.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER     MONEY  YTD VICTORIES
# 0     1         0      46970           Jon Rahm  $7705933            1.0
# 1     2         0      35450    Patrick Cantlay  $7638805            4.0
# 2     3         0      47959  Bryson DeChambeau  $7426415            2.0
# 3     4         0      50525    Collin Morikawa  $7059908            2.0
# 4     5         0      33448      Justin Thomas  $6537153            1.0

# %%
data_frameMO = data_frameMO[['PLAYER_ID', 'MONEY']]

# %%
# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameMO, on='PLAYER_ID', how='left')

# %%
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 3

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\P3 AVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP3 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP3.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID         PLAYER STATUS  PAR 3 AVG  TOTAL PAR
# 0     1         0      20229   Stewart Cink    -14       2.96       1074
# 1     2         0      46970       Jon Rahm    -12       2.96        924
# 2     3         0      22056  Cameron Percy    -10       2.97        930
# 3     4         0      40026  Daniel Berger     -6       2.98       1008
# 4     4         0      36801   Mark Hubbard     -6       2.98       1182

# %%
data_frameP3.rename(columns={'PAR 3 AVG': 'PAR_3_AVG'}, inplace=True)
data_frameP3 = data_frameP3[['PLAYER_ID', 'PAR_3_AVG']]

# %%
# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP3, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG
# 0       2.96
# 1       3.01
# 2       3.05
# 3       3.03
# 4       3.05

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 4

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\P4 AVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP4 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP4.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID           PLAYER  STATUS  PAR 4 AVG  TOTAL PAR
# 0     1         0      31646  Emiliano Grillo     -44       3.96       4088
# 1     2         0      35450  Patrick Cantlay     -43       3.95       3328
# 2     3         0      45526    Abraham Ancer     -38       3.96       4192
# 3     4         0      40026    Daniel Berger     -36       3.96       3624
# 4     5         0      30926       Chris Kirk     -35       3.96       3680

# %%
data_frameP4.rename(columns={'PAR 4 AVG': 'PAR_4_AVG'}, inplace=True)
data_frameP4 = data_frameP4[['PLAYER_ID', 'PAR_4_AVG']]

# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP4, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG
# 0       2.96       3.96
# 1       3.01       3.99
# 2       3.05       3.98
# 3       3.03       3.99
# 4       3.05       3.95

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PARES 5

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\P5 AVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameP5 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameP5.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER  STATUS  PAR 5 AVG  TOTAL PAR
# 0     1         0      39971         Sungjae Im    -174       4.57       2020
# 1     2         0      46046  Scottie Scheffler    -152       4.55       1690
# 2     3         0      34099     Harris English    -150       4.49       1460
# 3     4         0      45486    Joaquin Niemann    -147       4.54       1590
# 4     4         0      46970           Jon Rahm    -147       4.46       1350

# %%
data_frameP5.rename(columns={'PAR 5 AVG': 'PAR_5_AVG'}, inplace=True)
data_frameP5 = data_frameP5[['PLAYER_ID', 'PAR_5_AVG']]

# ENSAMBLAMOS EL MONEY DENTRO DEL DATA FRAME INICIAL

data_frame = data_frame.merge(data_frameP5, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG
# 0       2.96       3.96       4.46
# 1       3.01       3.99       4.54
# 2       3.05       3.98       4.54
# 3       3.03       3.99       4.45
# 4       3.05       3.95       4.52

# %%
# VAMOS A INCORPORAR LA ESTADISTICA DE PUTT AVERAGE

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\PUTT AVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_framePAVG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_framePAVG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID          PLAYER    AVG  GIR PUTTS  GREENS HIT  \
# 0     1         0      35891   Cameron Smith  1.689       1638         970
# 1     2         0      32757  Patton Kizzire  1.707       2123        1244
# 2     3         0      34046   Jordan Spieth  1.708       1747        1023
# 3     4         0      33597     Harry Higgs  1.709       1567         917
# 4     5         0      47504       Sam Burns  1.710       1753        1025
#
#    BIRDIE CONVERSION
# 0              37.47
# 1              34.11
# 2              36.06
# 3              35.27
# 4              35.59

# %%
data_framePAVG.rename(columns={'AVG': 'AVG_PUTT'}, inplace=True)

# %%
data_framePAVG = data_framePAVG[['PLAYER_ID', 'AVG_PUTT']]

# %%
# ENSAMBLAMOS EL AVG_PUTT DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_framePAVG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT
# 0       2.96       3.96       4.46     1.733
# 1       3.01       3.99       4.54     1.720
# 2       3.05       3.98       4.54     1.747
# 3       3.03       3.99       4.45     1.740
# 4       3.05       3.95       4.52     1.746

# %%
# VAMOS A INCORPORAR LA ESTADISTICA SCRAMBLING PROMEDIO

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SCAVG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSCAVG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSCAVG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID              PLAYER      %  PAR OR BETTER  \
# 0     1         0      35450     Patrick Cantlay  67.30            282
# 1     2         0      28252        Seamus Power  65.96            219
# 2     3         0      21961  Charles Howell III  65.86            272
# 3     4         0      25396            Kevin Na  65.12            366
# 4     5         0      29221        Webb Simpson  64.95            265
#
#    MISSED GIR
# 0         419
# 1         332
# 2         413
# 3         562
# 4         408

# %%
data_frameSCAVG.rename(columns={'%': 'AVG_SCRAMBLING'}, inplace=True)
data_frameSCAVG = data_frameSCAVG[['PLAYER_ID', 'AVG_SCRAMBLING']]

# %%
# ENSAMBLAMOS EL AVG_PUTT DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSCAVG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING
# 0       2.96       3.96       4.46     1.733           62.98
# 1       3.01       3.99       4.54     1.720           59.95
# 2       3.05       3.98       4.54     1.747           63.81
# 3       3.03       3.99       4.45     1.740           59.20
# 4       3.05       3.95       4.52     1.746           67.30

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED APPROACH THE GREEN 

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SG APP 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGAPP = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGAPP.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID           PLAYER    AVG  TOTAL SG:APP  \
# 0     1         0      50525  Collin Morikawa  1.170        77.191
# 1     2         0      25364       Paul Casey  0.895        51.920
# 2     3         0      33448    Justin Thomas  0.887        60.283
# 3     4         0      33141   Keegan Bradley  0.856        66.749
# 4     5         0      40026    Daniel Berger  0.834        60.915
#
#    MEASURED ROUNDS
# 0               66
# 1               58
# 2               68
# 3               78
# 4               73

# %%
data_frameSGAPP.rename(columns={'AVG': 'AVG_SG_APPROACH'}, inplace=True)
data_frameSGAPP = data_frameSGAPP[['PLAYER_ID', 'AVG_SG_APPROACH']]

# %%
# ENSAMBLAMOS EL AVG_SG_APPROACH DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGAPP, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH
# 0       2.96       3.96       4.46     1.733           62.98            0.717
# 1       3.01       3.99       4.54     1.720           59.95            0.315
# 2       3.05       3.98       4.54     1.747           63.81            0.459
# 3       3.03       3.99       4.45     1.740           59.20            0.291
# 4       3.05       3.95       4.52     1.746           67.30            0.486

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED ARROUND THE GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SG ATG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGATG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGATG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID         PLAYER    AVG  TOTAL SG:ARG  \
# 0     1         0      25396       Kevin Na  0.702        54.767
# 1     2         0      32139  Danny Willett  0.518        14.514
# 2     3         0      28679   Fabián Gómez  0.484        16.456
# 3     4         0      37455     Si Woo Kim  0.467        38.757
# 4     5         0      28252   Seamus Power  0.440        18.463
#
#    MEASURED ROUNDS
# 0               78
# 1               28
# 2               34
# 3               83
# 4               42

# %%
data_frameSGATG.rename(columns={'AVG': 'AVG_SG_ATG'}, inplace=True)
data_frameSGATG = data_frameSGATG[['PLAYER_ID', 'AVG_SG_ATG']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGATG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH  \
# 0       2.96       3.96       4.46     1.733           62.98            0.717
# 1       3.01       3.99       4.54     1.720           59.95            0.315
# 2       3.05       3.98       4.54     1.747           63.81            0.459
# 3       3.03       3.99       4.45     1.740           59.20            0.291
# 4       3.05       3.95       4.52     1.746           67.30            0.486
#
#    AVG_SG_ATG
# 0       0.216
# 1       0.147
# 2       0.353
# 3      -0.085
# 4       0.363

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED ARROUND THE GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SG PUTT 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSPUTT = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSPUTT.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID            PLAYER    AVG  TOTAL SG:PUTTING  \
# 0     1         0      26329  Louis Oosthuizen  0.764            45.852
# 1     2         0      49771       J.T. Poston  0.706            55.768
# 2     3         0      24138       Ian Poulter  0.695            38.241
# 3     4         0      34360      Patrick Reed  0.669            44.154
# 4     5         0      24024      Zach Johnson  0.667            50.655
#
#    MEASURED ROUNDS
# 0               60
# 1               79
# 2               55
# 3               66
# 4               76

# %%
data_frameSPUTT.rename(columns={'AVG': 'AVG_SG_PUTTING'}, inplace=True)
data_frameSPUTT = data_frameSPUTT[['PLAYER_ID', 'AVG_SG_PUTTING']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSPUTT, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH  \
# 0       2.96       3.96       4.46     1.733           62.98            0.717
# 1       3.01       3.99       4.54     1.720           59.95            0.315
# 2       3.05       3.98       4.54     1.747           63.81            0.459
# 3       3.03       3.99       4.45     1.740           59.20            0.291
# 4       3.05       3.95       4.52     1.746           67.30            0.486
#
#    AVG_SG_ATG  AVG_SG_PUTTING
# 0       0.216           0.331
# 1       0.147           0.429
# 2       0.353           0.764
# 3      -0.085           0.456
# 4       0.363           0.402

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED TOTAL

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SG TOTAL 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGTOT = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGTOT.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  TOTAL SG:T  \
# 0     1         0      46970           Jon Rahm  2.098     134.286
# 1     2         0      47959  Bryson DeChambeau  1.823     123.959
# 2     3         0      35450    Patrick Cantlay  1.820     123.758
# 3     4         0      26329   Louis Oosthuizen  1.599      95.967
# 4     5         0      48081  Xander Schauffele  1.484      93.464
#
#    TOTAL SG:T2G  TOTAL SG:P  MEASURED ROUNDS
# 0       113.113      21.174               64
# 1        92.967      30.993               68
# 2        96.411      27.349               68
# 3        50.115      45.852               60
# 4        63.250      30.215               63

# %%
data_frameSGTOT.rename(columns={'AVG': 'AVG_SG_TOTAL'}, inplace=True)
data_frameSGTOT = data_frameSGTOT[['PLAYER_ID', 'AVG_SG_TOTAL']]

# %%
# ENSAMBLAMOS EL AVG_SG_ATG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGTOT, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH  \
# 0       2.96       3.96       4.46     1.733           62.98            0.717
# 1       3.01       3.99       4.54     1.720           59.95            0.315
# 2       3.05       3.98       4.54     1.747           63.81            0.459
# 3       3.03       3.99       4.45     1.740           59.20            0.291
# 4       3.05       3.95       4.52     1.746           67.30            0.486
#
#    AVG_SG_ATG  AVG_SG_PUTTING  AVG_SG_TOTAL
# 0       0.216           0.331         2.098
# 1       0.147           0.429         1.253
# 2       0.353           0.764         1.599
# 3      -0.085           0.456         1.823
# 4       0.363           0.402         1.820

# %%
# VAMOS A INCORPORAR LA ESTADISTICA STROKES GAINED TEE TO GREEN

import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\SG TTG 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameSGTTG = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameSGTTG.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER    AVG  SG:OTT  SG:APR  \
# 0     1         0      46970           Jon Rahm  1.767   0.834   0.717
# 1     2         0      50525    Collin Morikawa  1.528   0.281   1.170
# 2     3         0      35450    Patrick Cantlay  1.418   0.569   0.486
# 3     3         0      33448      Justin Thomas  1.418   0.235   0.887
# 4     5         0      47959  Bryson DeChambeau  1.367   1.162   0.291
#
#    SG:ARG  MEASURED ROUNDS
# 0   0.216               64
# 1   0.077               66
# 2   0.363               68
# 3   0.296               68
# 4  -0.085               68

# %%
data_frameSGTTG

data_frameSGTTG.rename(columns={'AVG': 'AVG_SG_TTG'}, inplace=True)
data_frameSGTTG = data_frameSGTTG[['PLAYER_ID', 'AVG_SG_TTG']]

# %%
# ENSAMBLAMOS EL AVG_SG_TTG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameSGTTG, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  \
# 0                309.0        62.53        2003.0    71.93  $7705933
# 1                312.9        57.03        1510.0    66.67  $5001136
# 2                297.8        62.40        1877.0    67.64  $6306679
# 3                323.7        54.78        1910.0    67.15  $7426415
# 4                302.8        60.21        2056.0    70.16  $7638805
#
#    PAR_3_AVG  PAR_4_AVG  PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH  \
# 0       2.96       3.96       4.46     1.733           62.98            0.717
# 1       3.01       3.99       4.54     1.720           59.95            0.315
# 2       3.05       3.98       4.54     1.747           63.81            0.459
# 3       3.03       3.99       4.45     1.740           59.20            0.291
# 4       3.05       3.95       4.52     1.746           67.30            0.486
#
#    AVG_SG_ATG  AVG_SG_PUTTING  AVG_SG_TOTAL  AVG_SG_TTG
# 0       0.216           0.331         2.098       1.767
# 1       0.147           0.429         1.253       0.824
# 2       0.353           0.764         1.599       0.835
# 3      -0.085           0.456         1.823       1.367
# 4       0.363           0.402         1.820       1.418

# %%
# VAMOS A INCORPORAR LA ESTADISTICA TOP 10 Y WININGS
import pandas as pd

# Ruta al archivo CSV
csv_file_path = r'C:\Users\kikot\Desktop\TFM GOLF\2020\TOP 10 2020.csv'

# Cargar el archivo CSV en un DataFrame
data_frameTOP10 = pd.read_csv(csv_file_path)

# Mostrar las primeras filas del DataFrame
data_frameTOP10.head()
# Out:
#    RANK  MOVEMENT  PLAYER_ID             PLAYER  TOP 10  1ST  2ND  3RD
# 0     1         0      46970           Jon Rahm      15  1.0  2.0  2.0
# 1     2         0      45526      Abraham Ancer       9  1.0  1.0  NaN
# 2     2         0      47959  Bryson DeChambeau       9  2.0  1.0  1.0
# 3     2         0      30925     Dustin Johnson       9  1.0  1.0  NaN
# 4     2         0      34046      Jordan Spieth       9  1.0  2.0  2.0

# %%
data_frameTOP10.rename(columns={'1ST': 'WINS'}, inplace=True)
data_frameTOP10.rename(columns={'TOP 10': 'TOP10'}, inplace=True)
data_frameTOP10 = data_frameTOP10[['PLAYER_ID', 'WINS', 'TOP10']]

# %%
# ENSAMBLAMOS EL AVG_SG_TTG DENTRO DEL DF INICIAL

data_frame = data_frame.merge(data_frameTOP10, on='PLAYER_ID', how='left')
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  AVG_TOTAL_FOR_ROUND  TOTAL_ROUNDS  YEAR  \
# 0      46970           Jon Rahm               69.300            77  2020
# 1      30925     Dustin Johnson               69.619            72  2020
# 2      26329   Louis Oosthuizen               69.714            74  2020
# 3      47959  Bryson DeChambeau               69.728            80  2020
# 4      35450    Patrick Cantlay               69.736            78  2020
#
#    AVG_DRIVER_DISTANCE  AVG_FAIRWAY  FEDEX_POINTS  AVG_GIR     MONEY  ...  \
# 0                309.0        62.53        2003.0    71.93  $7705933  ...
# 1                312.9        57.03        1510.0    66.67  $5001136  ...
# 2                297.8        62.40        1877.0    67.64  $6306679  ...
# 3                323.7        54.78        1910.0    67.15  $7426415  ...
# 4                302.8        60.21        2056.0    70.16  $7638805  ...
#
#    PAR_5_AVG  AVG_PUTT  AVG_SCRAMBLING  AVG_SG_APPROACH  AVG_SG_ATG  \
# 0       4.46     1.733           62.98            0.717       0.216
# 1       4.54     1.720           59.95            0.315       0.147
# 2       4.54     1.747           63.81            0.459       0.353
# 3       4.45     1.740           59.20            0.291      -0.085
# 4       4.52     1.746           67.30            0.486       0.363
#
#    AVG_SG_PUTTING  AVG_SG_TOTAL  AVG_SG_TTG  WINS  TOP10
# 0           0.331         2.098       1.767   1.0   15.0
# 1           0.429         1.253       0.824   1.0    9.0
# 2           0.764         1.599       0.835   4.0    8.0
# 3           0.456         1.823       1.367   2.0    9.0
# 4           0.402         1.820       1.418   4.0    7.0
#
# [5 rows x 22 columns]

# %%
# Define el orden deseado de las columnas
column_order = ['PLAYER_ID', 'PLAYER_NAME', 'TOTAL_ROUNDS', 'AVG_FAIRWAY', 'AVG_SCRAMBLING', 'AVG_TOTAL_FOR_ROUND', 'AVG_DRIVER_DISTANCE','AVG_SG_APPROACH', 'AVG_GIR', 'AVG_PUTT', 'AVG_SG_ATG', 'AVG_SG_PUTTING', 'AVG_SG_TOTAL', 'AVG_SG_TTG','PAR_5_AVG','PAR_4_AVG','PAR_3_AVG', 'WINS', 'TOP10', 'YEAR', 'FEDEX_POINTS', 'MONEY']

# Reordena las columnas en el DataFrame
data_frame = data_frame[column_order]

# Mostrar el DataFrame con las columnas ordenadas
data_frame.head()
# Out:
#    PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS  AVG_FAIRWAY  AVG_SCRAMBLING  \
# 0      46970           Jon Rahm            77        62.53           62.98
# 1      30925     Dustin Johnson            72        57.03           59.95
# 2      26329   Louis Oosthuizen            74        62.40           63.81
# 3      47959  Bryson DeChambeau            80        54.78           59.20
# 4      35450    Patrick Cantlay            78        60.21           67.30
#
#    AVG_TOTAL_FOR_ROUND  AVG_DRIVER_DISTANCE  AVG_SG_APPROACH  AVG_GIR  \
# 0               69.300                309.0            0.717    71.93
# 1               69.619                312.9            0.315    66.67
# 2               69.714                297.8            0.459    67.64
# 3               69.728                323.7            0.291    67.15
# 4               69.736                302.8            0.486    70.16
#
#    AVG_PUTT  ...  AVG_SG_TOTAL  AVG_SG_TTG  PAR_5_AVG  PAR_4_AVG  PAR_3_AVG  \
# 0     1.733  ...         2.098       1.767       4.46       3.96       2.96
# 1     1.720  ...         1.253       0.824       4.54       3.99       3.01
# 2     1.747  ...         1.599       0.835       4.54       3.98       3.05
# 3     1.740  ...         1.823       1.367       4.45       3.99       3.03
# 4     1.746  ...         1.820       1.418       4.52       3.95       3.05
#
#    WINS  TOP10  YEAR  FEDEX_POINTS     MONEY
# 0   1.0   15.0  2020        2003.0  $7705933
# 1   1.0    9.0  2020        1510.0  $5001136
# 2   4.0    8.0  2020        1877.0  $6306679
# 3   2.0    9.0  2020        1910.0  $7426415
# 4   4.0    7.0  2020        2056.0  $7638805
#
# [5 rows x 22 columns]

# %%
num_rows, num_columns = data_frame.shape
print("Número de filas:", num_rows)
print("Número de columnas:", num_columns)
# Out:
# Número de filas: 196
# Número de columnas: 22

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID               0
# PLAYER_NAME             0
# TOTAL_ROUNDS            0
# AVG_FAIRWAY             0
# AVG_SCRAMBLING          0
# AVG_TOTAL_FOR_ROUND     0
# AVG_DRIVER_DISTANCE     0
# AVG_SG_APPROACH         0
# AVG_GIR                 0
# AVG_PUTT                0
# AVG_SG_ATG              0
# AVG_SG_PUTTING          0
# AVG_SG_TOTAL            0
# AVG_SG_TTG              0
# PAR_5_AVG               0
# PAR_4_AVG               0
# PAR_3_AVG               0
# WINS                   92
# TOP10                  35
# YEAR                    0
# FEDEX_POINTS            1
# MONEY                   0
# dtype: int64

# %%
# Reemplazar los valores NaN por 0 en todo el DataFrame
df_filled = data_frame.fillna(0)

# Mostrar el DataFrame con los valores NaN reemplazados por 0
print(df_filled)
# Out:
#      PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS  AVG_FAIRWAY  AVG_SCRAMBLING  \
# 0        46970           Jon Rahm            77        62.53           62.98
# 1        30925     Dustin Johnson            72        57.03           59.95
# 2        26329   Louis Oosthuizen            74        62.40           63.81
# 3        47959  Bryson DeChambeau            80        54.78           59.20
# 4        35450    Patrick Cantlay            78        60.21           67.30
# ..         ...                ...           ...          ...             ...
# 191      27095        Nick Watney            54        53.91           56.38
# 192      39975        Michael Kim            69        48.49           56.73
# 193      34213     Grayson Murray            49        50.10           46.67
# 194      35617     Martin Trainer            59        50.46           56.24
# 195      24781       Hunter Mahan            57        56.97           53.90
#
#      AVG_TOTAL_FOR_ROUND  AVG_DRIVER_DISTANCE  AVG_SG_APPROACH  AVG_GIR  \
# 0                 69.300                309.0            0.717    71.93
# 1                 69.619                312.9            0.315    66.67
# 2                 69.714                297.8            0.459    67.64
# 3                 69.728                323.7            0.291    67.15
# 4                 69.736                302.8            0.486    70.16
# ..                   ...                  ...              ...      ...
# 191               72.787                299.3           -0.205    65.33
# 192               72.809                293.2            0.022    61.11
# 193               73.115                305.5           -0.260    62.59
# 194               73.131                303.6           -1.458    55.46
# 195               73.201                296.2           -1.601    57.50
#
#      AVG_PUTT  ...  AVG_SG_TOTAL  AVG_SG_TTG  PAR_5_AVG  PAR_4_AVG  PAR_3_AVG  \
# 0       1.733  ...         2.098       1.767       4.46       3.96       2.96
# 1       1.720  ...         1.253       0.824       4.54       3.99       3.01
# 2       1.747  ...         1.599       0.835       4.54       3.98       3.05
# 3       1.740  ...         1.823       1.367       4.45       3.99       3.03
# 4       1.746  ...         1.820       1.418       4.52       3.95       3.05
# ..        ...  ...           ...         ...        ...        ...        ...
# 191     1.824  ...        -1.442      -0.983       4.81       4.07       3.13
# 192     1.829  ...        -1.369      -1.209       4.71       4.16       3.03
# 193     1.801  ...        -2.108      -0.846       4.75       4.13       3.18
# 194     1.784  ...        -1.781      -2.057       4.74       4.13       3.20
# 195     1.773  ...        -1.788      -2.279       4.81       4.10       3.25
#
#      WINS  TOP10  YEAR  FEDEX_POINTS     MONEY
# 0     1.0   15.0  2020        2003.0  $7705933
# 1     1.0    9.0  2020        1510.0  $5001136
# 2     4.0    8.0  2020        1877.0  $6306679
# 3     2.0    9.0  2020        1910.0  $7426415
# 4     4.0    7.0  2020        2056.0  $7638805
# ..    ...    ...   ...           ...       ...
# 191   0.0    0.0  2020          89.0   $159576
# 192   0.0    0.0  2020          44.0   $132613
# 193   1.0    1.0  2020         122.0   $255130
# 194   0.0    0.0  2020          25.0    $60284
# 195   0.0    0.0  2020          18.0    $58600
#
# [196 rows x 22 columns]

# %%
# Reemplazar los valores NaN por 0 en todo el DataFrame
data_frame = data_frame.fillna(0)

# Mostrar el DataFrame con los valores NaN reemplazados por 0
print(data_frame)
# Out:
#      PLAYER_ID        PLAYER_NAME  TOTAL_ROUNDS  AVG_FAIRWAY  AVG_SCRAMBLING  \
# 0        46970           Jon Rahm            77        62.53           62.98
# 1        30925     Dustin Johnson            72        57.03           59.95
# 2        26329   Louis Oosthuizen            74        62.40           63.81
# 3        47959  Bryson DeChambeau            80        54.78           59.20
# 4        35450    Patrick Cantlay            78        60.21           67.30
# ..         ...                ...           ...          ...             ...
# 191      27095        Nick Watney            54        53.91           56.38
# 192      39975        Michael Kim            69        48.49           56.73
# 193      34213     Grayson Murray            49        50.10           46.67
# 194      35617     Martin Trainer            59        50.46           56.24
# 195      24781       Hunter Mahan            57        56.97           53.90
#
#      AVG_TOTAL_FOR_ROUND  AVG_DRIVER_DISTANCE  AVG_SG_APPROACH  AVG_GIR  \
# 0                 69.300                309.0            0.717    71.93
# 1                 69.619                312.9            0.315    66.67
# 2                 69.714                297.8            0.459    67.64
# 3                 69.728                323.7            0.291    67.15
# 4                 69.736                302.8            0.486    70.16
# ..                   ...                  ...              ...      ...
# 191               72.787                299.3           -0.205    65.33
# 192               72.809                293.2            0.022    61.11
# 193               73.115                305.5           -0.260    62.59
# 194               73.131                303.6           -1.458    55.46
# 195               73.201                296.2           -1.601    57.50
#
#      AVG_PUTT  ...  AVG_SG_TOTAL  AVG_SG_TTG  PAR_5_AVG  PAR_4_AVG  PAR_3_AVG  \
# 0       1.733  ...         2.098       1.767       4.46       3.96       2.96
# 1       1.720  ...         1.253       0.824       4.54       3.99       3.01
# 2       1.747  ...         1.599       0.835       4.54       3.98       3.05
# 3       1.740  ...         1.823       1.367       4.45       3.99       3.03
# 4       1.746  ...         1.820       1.418       4.52       3.95       3.05
# ..        ...  ...           ...         ...        ...        ...        ...
# 191     1.824  ...        -1.442      -0.983       4.81       4.07       3.13
# 192     1.829  ...        -1.369      -1.209       4.71       4.16       3.03
# 193     1.801  ...        -2.108      -0.846       4.75       4.13       3.18
# 194     1.784  ...        -1.781      -2.057       4.74       4.13       3.20
# 195     1.773  ...        -1.788      -2.279       4.81       4.10       3.25
#
#      WINS  TOP10  YEAR  FEDEX_POINTS     MONEY
# 0     1.0   15.0  2020        2003.0  $7705933
# 1     1.0    9.0  2020        1510.0  $5001136
# 2     4.0    8.0  2020        1877.0  $6306679
# 3     2.0    9.0  2020        1910.0  $7426415
# 4     4.0    7.0  2020        2056.0  $7638805
# ..    ...    ...   ...           ...       ...
# 191   0.0    0.0  2020          89.0   $159576
# 192   0.0    0.0  2020          44.0   $132613
# 193   1.0    1.0  2020         122.0   $255130
# 194   0.0    0.0  2020          25.0    $60284
# 195   0.0    0.0  2020          18.0    $58600
#
# [196 rows x 22 columns]

# %%
data_frame2020 = data_frame

# %%
# Ruta para guardar el archivo CSV
ruta_guardado = r'C:\Users\kikot\Desktop\TFM GOLF\data_frame2020.csv'

# Exportar el DataFrame a un archivo CSV en la ruta especificada
data_frame2020.to_csv(ruta_guardado, index=False)

# %%
# Contar el número de valores NaN en cada columna
num_nans_per_column = data_frame.isna().sum()

# Mostrar el número de valores NaN por columna
print(num_nans_per_column)
# Out:
# PLAYER_ID              0
# PLAYER_NAME            0
# TOTAL_ROUNDS           0
# AVG_FAIRWAY            0
# AVG_SCRAMBLING         0
# AVG_TOTAL_FOR_ROUND    0
# AVG_DRIVER_DISTANCE    0
# AVG_SG_APPROACH        0
# AVG_GIR                0
# AVG_PUTT               0
# AVG_SG_ATG             0
# AVG_SG_PUTTING         0
# AVG_SG_TOTAL           0
# AVG_SG_TTG             0
# PAR_5_AVG              0
# PAR_4_AVG              0
# PAR_3_AVG              0
# WINS                   0
# TOP10                  0
# YEAR                   0
# FEDEX_POINTS           0
# MONEY                  0
# dtype: int64
